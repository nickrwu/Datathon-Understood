# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/home/jovyan/work/Ecosystem.csv")

# %%
data.head()
# Out:
#               Organization                                        Org Website  \
# 0             Khan Academy                       https://www.khanacademy.org/
# 1                     AHRC  https://www.ahrcnyc.org/services/school/ahrc-n...
# 2  Headspace For Educators       https://www.headspace.com/educators-covid-19
# 3        The Chopra Center                                https://chopra.com/
# 4                 Calm.com                    https://www.calm.com/blog/about
#
#                          Moment 1  \
# 0  S1 - Confusion,S2 - Comparison
# 1                 S2 - Comparison
# 2     S3 - Coping,S4 - Acceptance
# 3     S3 - Coping,S4 - Acceptance
# 4                     S3 - Coping
#
#                                             Moment 2 Moment 3 Moment 4  \
# 0  S2 - Comparison,S1 - Fear,S3 - Trying,S4 - Mas...      NaN      NaN
# 1                                                NaN      NaN      NaN
# ...

# %%
np.shape(data)
# Out:
# (348, 17)

# %%
data.drop(["Moment 1", "Moment 2", "Moment 3", "Moment 4", "Type of Org Expanded"\
, "Keyword Expanded", "Target Audience"], axis = 1, inplace = True)

# %%
data
# Out:
#                               Organization  \
# 0                             Khan Academy
# 1                                     AHRC
# 2                  Headspace For Educators
# 3                        The Chopra Center
# 4                                 Calm.com
# ..                                     ...
# 343           Division for Early Childhood
# 344                     Reach Out and Read
# 345                      Too Small to Fail
# 346  Smart Kids with Learning Disabilities
# 347      Learning Disabilities Association
#
#                                            Org Website  Type of Org  \
# 0                         https://www.khanacademy.org/   Non-Profit
# 1    https://www.ahrcnyc.org/services/school/ahrc-n...   Non-Profit
# 2         https://www.headspace.com/educators-covid-19  Corporation
# 3                                  https://chopra.com/  Corporation
# 4                      https://www.calm.com/blog/about  Corporation
# ...

# %%
data_copy = data.copy()

# %%
data_copy.rename({'Type of Org': 'Type_of_Org'}, axis=1, inplace=True)

# %%
data_copy = data_copy[data_copy.Type_of_Org == "Non-Profit"]

# %%
data_copy
# Out:
#                                           Organization  \
# 0                                         Khan Academy
# 1                                                 AHRC
# 7    Metropolitan Center for Research on Equity and...
# 8                                       Education Week
# 10   YAI - Young Adult Institute "Seeing Beyond Dis...
# ..                                                 ...
# 343                       Division for Early Childhood
# 344                                 Reach Out and Read
# 345                                  Too Small to Fail
# 346              Smart Kids with Learning Disabilities
# 347                  Learning Disabilities Association
#
#                                            Org Website Type_of_Org  \
# 0                         https://www.khanacademy.org/  Non-Profit
# 1    https://www.ahrcnyc.org/services/school/ahrc-n...  Non-Profit
# 7               https://steinhardt.nyu.edu/metrocenter  Non-Profit
# ...
