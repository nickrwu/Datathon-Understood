# %%
# large company? 

import pandas as pd
data = pd.read_csv("Data/partners.csv")
data.head()
# Out:
#                               Org Name         EIN Current FY Start  \
# 0  CHC: Creating Healthier Communities  13-6167225       2018-07-01
# 1                           CAST, Inc.  22-2746879       2017-10-01
# 2                             BENETECH  77-0555413       2018-01-01
# 3             CHILD MIND INSTITUTE INC  80-0478843       2017-10-01
# 4                           New Profit  04-3396766       2018-01-01
#
#   Current FY End  Ruling Year  Form Year Form Type  \
# 0     2019-06-30         1985     2018.0       990
# 1     2018-09-30         1986     2017.0       990
# 2     2018-12-31         2001     2018.0       990
# 3     2018-09-30         2009     2017.0       990
# 4     2018-12-31         1998     2018.0       990
#
#                 Address Line 1 Address Line 2        City  ... Legal Fees  \
# 0            1199 N Fairfax St        Ste 600  Alexandria  ...    $88,730
# 1  200 Harvard Mill Sq Ste 210            NaN   Wakefield  ...    $11,078
# ...

# %%
df = data['Number of Employees']
print(df)
# Out:
# 0      55.0
# 1      51.0
# 2      86.0
# 3     111.0
# 4      74.0
# 5      70.0
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10    182.0
# 11     27.0
# 12     45.0
# 13    189.0
# 14    800.0
# 15      NaN
# 16      NaN
# 17    245.0
# 18    497.0
# Name: Number of Employees, dtype: float64

# %%
#how to deal with the nan? delete the nan and compute the average as one of the criteria
df = df.dropna()
print(df)
# Out:
# 0      55.0
# 1      51.0
# 2      86.0
# 3     111.0
# 4      74.0
# 5      70.0
# 10    182.0
# 11     27.0
# 12     45.0
# 13    189.0
# 14    800.0
# 17    245.0
# 18    497.0
# Name: Number of Employees, dtype: float64

# %%
df = df.tolist()
print(df)
# Out:
# [55.0, 51.0, 86.0, 111.0, 74.0, 70.0, 182.0, 27.0, 45.0, 189.0, 800.0, 245.0, 497.0]

# %%
a = (df[6]+df[7])
print(round(a/2))
# Out:
# 104
